# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/PKIEC5/blob/main/python_variabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
nama="Deni"
Nama='Ajis'
print("Nama")
print(nama)
print(Nama)
# Out:
# hello world
# Nama
# Deni
# Ajis

# %%
print(f"Hello {nama} kenalkan saya {Nama}")
# Out:
# Hello Deni kenalkan saya Ajis

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
a=1
b=-2
c=-8

d=b*b-4*a*c
print(f"Nilai D={d}")
# Out:
# Nilai D=36

# %%
x1=(-b+math.sqrt(d))/(2*a)
x2=(-b-math.sqrt(d))/(2*a)

print(f"Nilai x1={x1}")
print(f"Nilai x2={x2}")
# Out:
# Nilai x1=4.0
# Nilai x2=-2.0

# %%
#INPUT
a,b,c=1,-16,64

#PROCESS
d=b*b-4*a*c
x1=(-b+math.sqrt(d))/(2*a)
x2=(-b-math.sqrt(d))/(2*a)

#OUTPUT
print(f"Nilai D={d}")
print(f"Nilai x1={x1}")
print(f"Nilai x2={x2}")
# Out:
# Nilai D=0
# Nilai x1=8.0
# Nilai x2=8.0

# %%
###TUGASSS APEL-JERUK

h_apel=5000
h_jeruk=4000

qty_beli_apel=3
qty_beli_jeruk=2

tot_beli_apel=h_apel*qty_beli_apel
tot_beli_jeruk=h_jeruk*qty_beli_jeruk

total_belanja=tot_beli_apel+tot_beli_jeruk


print(f"Total beli apel : Rp.{tot_beli_apel}")
print(f"Total beli jeruk : Rp.{tot_beli_jeruk}")
print(f"Total Belanja : Rp.{total_belanja}")
# Out:
# Total beli apel : Rp.15000
# Total beli jeruk : Rp.8000
# Total Belanja : Rp.23000
